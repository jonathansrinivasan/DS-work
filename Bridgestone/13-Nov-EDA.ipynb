# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
nov15=pd.read_csv("Nov15.csv", low_memory=False)
nov16=pd.read_csv("Nov16.csv", low_memory=False)
nov17=pd.read_csv("Nov17.csv", low_memory=False)

# %%
print(nov15.head())
# Out:
#    Unnamed: 0  STORE_ID    TRAN_ID        DATE  ARTICLE_ID     INDIV_ID  \
# 0           0     10324  991732880  2015-11-22     7005219  316768492.0
# 1           1     10324  991732880  2015-11-22     7005180  316768492.0
# 2           2     10324  991732880  2015-11-22     7005229  316768492.0
# 3           3    533521  992123290  2015-11-05     7005937  302230226.0
# 4           4    533521  992123290  2015-11-05     7028789  302230226.0
#
#    VEHICLE_ID  UNITS   SALES STATE_CODE  ...               SEGMENT_DESC  \
# 0   944022419    0.0    0.00         VA  ...                 Alignments
# 1   944022419    0.0  -20.00         VA  ...                 Alignments
# 2   944022419    0.0  199.99         VA  ...                 Alignments
# 3   937607995    1.0  139.99         FL  ...  Starting/Charging Systems
# 4   937607995    0.0   19.99         FL  ...        Inspection Services
#
#   CLASS_CODE                        CLASS_DESC DISCOUNT_FLAG CROSS_SECTION  \
# ...

# %%
sns.heatmap(nov15.corr())

# %%
bool_series = pd.isnull(nov15['SEGMENT_DESC'])
bool_series
# Out:
# 0           False
# 1           False
# 2           False
# 3           False
# 4           False
#             ...
# 15394332    False
# 15394333    False
# 15394334    False
# 15394335    False
# 15394336    False
# Name: SEGMENT_DESC, Length: 15394337, dtype: bool

# %%
nov15.describe
# Out:
# <bound method NDFrame.describe of           Unnamed: 0  STORE_ID    TRAN_ID        DATE  ARTICLE_ID  \
# 0                  0     10324  991732880  2015-11-22     7005219
# 1                  1     10324  991732880  2015-11-22     7005180
# 2                  2     10324  991732880  2015-11-22     7005229
# 3                  3    533521  992123290  2015-11-05     7005937
# 4                  4    533521  992123290  2015-11-05     7028789
# ...              ...       ...        ...         ...         ...
# 15394332    15394332      4871  880295510  2015-11-20      117768
# 15394333    15394333      4057  880168820  2015-11-27       84856
# 15394334    15394334    592196  991702840  2015-11-02     7020729
# 15394335    15394335      4154  880160320  2015-11-11      112345
# 15394336    15394336     19461  880468910  2015-11-17      117649
#
#              INDIV_ID  VEHICLE_ID  UNITS   SALES STATE_CODE  ...  \
# 0         316768492.0   944022419    0.0    0.00         VA  ...
# ...

# %%
nov15.isnull().sum()
# Out:
# Unnamed: 0                 0
# STORE_ID                   0
# TRAN_ID                    0
# DATE                       0
# ARTICLE_ID                 0
# INDIV_ID                5807
# VEHICLE_ID                 0
# UNITS                      0
# SALES                      0
# STATE_CODE                 0
# ZIP_CODE                   0
# MSA                  2779160
# MAKE                  247672
# MODEL                 247630
# SUB_MODEL            2539568
# MODEL_YEAR            247628
# PROD_GROUP_CODE            0
# PROD_GROUP_DESC            0
# CATEGORY_CODE              0
# CATEGORY_DESC              0
# SEGMENT_CODE               0
# SEGMENT_DESC               0
# CLASS_CODE                 0
# CLASS_DESC                 0
# DISCOUNT_FLAG              0
# CROSS_SECTION       14156384
# ASPECT_RATIO        14156384
# RIM_SIZE            14175973
# EMAIL_OPTIN_IND      5471821
# AH1_RES_BUS_INDC     5811996
# SUPP1_BUS_PANDER     5811996
# dtype: int64

# %%
print(nov16.head())
sns.heatmap(nov16.corr())
# Out:
#    Unnamed: 0  STORE_ID    TRAN_ID        DATE  ARTICLE_ID     INDIV_ID  \
# 0           0     74802  990916120  2016-11-07     7001671  314158861.0
# 1           1     74802  990916120  2016-11-07     7013632  314158861.0
# 2           2     74802  990916120  2016-11-07     7001671  314158861.0
# 3           3     74802  990916120  2016-11-07     7001127  314158861.0
# 4           4     74802  990916120  2016-11-07     7006016  314158861.0
#
#    VEHICLE_ID  UNITS  SALES STATE_CODE  ...            SEGMENT_DESC  \
# 0   943077622    0.0 -13.00         FL  ...  Discount Misc Services
# 1   943077622    0.0  47.96         FL  ...           Tire Services
# 2   943077622    0.0   0.00         FL  ...  Discount Misc Services
# 3   943077622    0.0   0.00         FL  ...   Discount All Services
# 4   943077622    0.0   0.00         FL  ...           Tire Services
#
#   CLASS_CODE              CLASS_DESC DISCOUNT_FLAG CROSS_SECTION  \
# ...

# %%
nov15.nunique()
# Out:
# Unnamed: 0          15394337
# STORE_ID                2198
# TRAN_ID               280573
# DATE                      30
# ARTICLE_ID              7600
# INDIV_ID             1448801
# VEHICLE_ID           1434524
# UNITS                     85
# SALES                  45017
# STATE_CODE                48
# ZIP_CODE                1941
# MSA                      311
# MAKE                     405
# MODEL                   7401
# SUB_MODEL               3854
# MODEL_YEAR                94
# PROD_GROUP_CODE            3
# PROD_GROUP_DESC            3
# CATEGORY_CODE             16
# CATEGORY_DESC             16
# SEGMENT_CODE              54
# SEGMENT_DESC              55
# CLASS_CODE               166
# CLASS_DESC               162
# DISCOUNT_FLAG              3
# CROSS_SECTION             36
# ASPECT_RATIO              20
# RIM_SIZE                  19
# EMAIL_OPTIN_IND            3
# AH1_RES_BUS_INDC           3
# SUPP1_BUS_PANDER           2
# dtype: int64

# %%
print(nov17.head())
sns.heatmap(nov17.corr())
# Out:
#    Unnamed: 0  STORE_ID    TRAN_ID        DATE  ARTICLE_ID     INDIV_ID  \
# 0           0     16926  992052810  2017-11-30     7001674  637925357.0
# 1           1     16926  992052810  2017-11-30     7001674  637925357.0
# 2           2     16926  992052810  2017-11-30     7001674  637925357.0
# 3           3     16926  992052810  2017-11-30     7001674  637925357.0
# 4           4     16926  992052810  2017-11-30     7029718  637925357.0
#
#    VEHICLE_ID  UNITS  SALES STATE_CODE  ...          SEGMENT_DESC CLASS_CODE  \
# 0   928430923    0.0   0.00         MN  ...  Lubrication Services      389.0
# 1   928430923    0.0   0.00         MN  ...  Lubrication Services      389.0
# 2   928430923    0.0  -1.28         MN  ...  Lubrication Services      389.0
# 3   928430923    0.0  -7.95         MN  ...  Lubrication Services      389.0
# 4   928430923    0.0   5.00         MN  ...  Lubrication Services      389.0
#
#    CLASS_DESC DISCOUNT_FLAG CROSS_SECTION  ASPECT_RATIO  RIM_SIZE  \
# ...
